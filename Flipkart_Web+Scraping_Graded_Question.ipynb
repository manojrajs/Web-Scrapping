# %% [markdown]
# ## HTML Page Read and Upload

# %%
# Import useful libraries and classes.
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
#html page upload and read in web_page variable.
my_url=  "https://www.flipkart.com/search?p%5B%5D=facets.brand%255B%255D%3DSamsung&sid=tyy%2F4io&sort=recency_desc&wid=1.productCard.PMU_V2_1"
web_page= uReq(my_url)
page_html= web_page.read()

# %% [markdown]
# ## Parsing

# %%
#html parser. It is to beautify the HTML code.
page_soup= soup(page_html)
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ## Extraction of information

# %%
#read class attribute from web page in containers variable.
# Print the length of containers.
containers= page_soup.findAll("div", {"class": "_2kHMtA"})
print(len(containers))
# Out:
# 24

# %%
# Extract the model name of 6th phone in the list.

model_name_phone= containers[5].findAll("div", {"class": "_4rR01T"})

print(model_name_phone[0].text.strip())
# Out:
# SAMSUNG Galaxy M14 5G (Smoky Teal, 128 GB)

# %%
# how many elements does 'tVe95H' class contained in it?
Specs_phone= containers[7].findAll("li", {"class": "rgWa7D"})

print(Specs_phone[2].text.strip())
# Out:
# 50MP Rear Camera

# %%
from urllib.request import urlopen as ureq
from bs4 import BeautifulSoup as Soup

# %%
myurl = r"https://www.flipkart.com/laptops/~laptops-under-rs50000/pr?sid=6bo%2Cb5g"
myclient = ureq(myurl)
pag_html = myclient.read()
myclient.close()

# %%
pag_soup = Soup(pag_html)
pag_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
containers = pag_soup.findAll("div",{"class":"_2kHMtA"})
print(len(containers))
# Out:
# 24

# %%
containers
# Out:
# [<div class="_2kHMtA"><div class="_2tfzpE"><span>Ad</span></div><a class="_1fQZEK" href="/hp-ryzen-3-quad-core-5300u-8-gb-512-gb-ssd-windows-11-home-15s-eq2143au-thin-light-laptop/p/itm833bca55e158b?pid=COMGAX8EEYFKCESS&amp;lid=LSTCOMGAX8EEYFKCESS83R2QP&amp;marketplace=FLIPKART&amp;store=6bo%2Fb5g&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=en_5wVdFbjmZ9z6VgySqVJ0oflu9forfOoWi9PvSJrOSl%2F4VDvb1GsELeQzBi%2FF9jJfjaaUETY0LOlIEdMCbtQv6Q%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=x940p74y1c0000001685605984124" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="HP Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/Windows 11 Home) 15s-eq2143au Thin and Light Laptop" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/computer/x/u/6/-original-imagp7pfd65hfses.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><l
# ...

# %%
for container in containers:
    prd = container.findAll("div",{"class":"_4rR01T"})
    L_N = prd[0].text.split("-")[0]
    print(L_N)
# Out:
# HP Ryzen 3 Quad Core 5300U
# Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen
# ASUS Vivobook 15 Core i3 11th Gen
# HP 247 G8 Athlon Dual Core
# realme Book (Slim) Core i3 11th Gen
# ASUS Vivobook 15 Core i5 11th Gen
# Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen
# Lenovo IdeaPad 3 Core i3 11th Gen
# acer Extensa (2023) Ryzen 5 Quad Core 7520U
# Lenovo ThinkBook 15 Ryzen 3 Hexa Core 5300U
# ASUS Vivobook K15 OLED Ryzen 5 Hexa Core AMD R5
# HP Ryzen 5 Hexa Core 5500U
# HP 15s (2023) Ryzen 3 Dual Core 3250U
# HP 14s Intel Core i3 11th Gen
# HP 15s Intel Core i3 11th Gen
# Lenovo IdeaPad 3 Intel Core i3 11th Gen
# Lenovo IdeaPad 3 Core i3 12th Gen
# Infinix Y1 Plus Neo Intel Celeron Quad Core 11th Gen
# HP Laptop Core i3 11th Gen
# HP Ryzen 5 Hexa Core 5500U
# ASUS Chromebook Touch Intel Celeron Dual Core
# HP 14s Intel Core i3 11th Gen
# ASUS Vivobook 15 Core i3 11th Gen
# Lenovo IdeaPad Slim 3 Intel Core i3 12th Gen
